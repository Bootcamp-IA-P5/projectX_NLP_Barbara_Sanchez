# %% [markdown]
# # Integración con YouTube
#
# Este notebook demuestra cómo usar el módulo de integración con YouTube para extraer y analizar comentarios de videos.

# %%
# Imports
import sys
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Añadir src al path
project_root = Path().resolve().parent
src_path = project_root / 'src'
if str(src_path) not in sys.path:
    sys.path.insert(0, str(src_path))

from utils.youtube import (
    extract_video_id,
    extract_comments,
    analyze_video_comments,
    save_analysis_results
)
from api.predict import load_predictor

print("✅ Módulos importados correctamente")
# Out:
# ✅ Módulos importados correctamente

# %% [markdown]
# ## 1. Cargar Modelo

# %%
# Cargar predictor
predictor = load_predictor()
print("✅ Modelo cargado")
# Out:
# ✅ Vectorizador cargado desde: /Users/barbara/Desktop/bootcamp IA/projectX_NLP_B-rbara_S-nchez/models/tfidf_vectorizer.pkl
# ✅ spaCy cargado: en_core_web_sm
# ✅ Modelo cargado desde: /Users/barbara/Desktop/bootcamp IA/projectX_NLP_B-rbara_S-nchez/models/optimized/best_optimized_model.pkl
# ✅ Vectorizador cargado desde: /Users/barbara/Desktop/bootcamp IA/projectX_NLP_B-rbara_S-nchez/models/tfidf_vectorizer.pkl
# ✅ Modelo cargado

# %% [markdown]
# ## 2. Extraer ID de Video

# %%
# URL de ejemplo (reemplazar con una URL real)
video_url = "https://www.youtube.com/watch?v=dQw4w9WgXcQ"

# Extraer ID
video_id = extract_video_id(video_url)
print(f"URL: {video_url}")
print(f"ID del video: {video_id}")
# Out:
# URL: https://www.youtube.com/watch?v=dQw4w9WgXcQ
# ID del video: dQw4w9WgXcQ

# %% [markdown]
# ## 3. Analizar Comentarios con el Modelo

# %%
# Analizar comentarios
df_results = analyze_video_comments(
    video_url,
    predictor,
    max_comments=100,
    sort_by='top'
)

print(f"\n📊 DataFrame con resultados:")
print(df_results.head())
# Out:
# 📥 Extrayendo comentarios de: https://www.youtube.com/watch?v=dQw4w9WgXcQ
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[12], line 2
#       1 # Analizar comentarios
# ----> 2 df_results = analyze_video_comments(
#       3     video_url,
#       4     predictor,
#       5     max_comments=100,
#       6     sort_by='top'
#       7 )
#       9 print(f"\n📊 DataFrame con resultados:")
#      10 print(df_results.head())
#
# File ~/Desktop/bootcamp IA/projectX_NLP_B-rbara_S-nchez/src/utils/youtube.py:148, in analyze_video_comments(video_url, predictor, max_comments, sort_by)
#     135 """
#     136 Extraer y analizar comentarios de un video de YouTube.
#     137
#    (...)    145     DataFrame con comentarios y predicciones
#     146 """
#     147 print(f"📥 Extrayendo comentarios de: {video_url}")
# ...
