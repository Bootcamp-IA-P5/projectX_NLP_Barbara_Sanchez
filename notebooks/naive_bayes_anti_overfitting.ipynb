# %% [markdown]
# # Naive Bayes - Reducción de Overfitting
#
# ## Objetivo
# Probar Naive Bayes con técnicas anti-overfitting como alternativa a modelos más complejos para reducir overfitting manteniendo F1-score > 0.55.
#
# ## Ventajas de Naive Bayes
# - ✅✅✅ Modelo simple (menos propenso a overfitting)
# - ✅✅✅ Regularización incorporada (parámetro alpha)
# - ✅✅✅ Rápido de entrenar y predecir
# - ✅✅✅ Funciona bien con TF-IDF
# - ✅✅✅ Menos parámetros = menos riesgo de sobreajuste
# - ✅ Buen baseline para comparar con otros modelos

# %% [markdown]
# ## 1. Importación de librerías

# %%
import pandas as pd
import numpy as np
import pickle
import random

from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import cross_val_score, StratifiedKFold
import optuna

from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    confusion_matrix
)

np.random.seed(42)
random.seed(42)

print("✅ Librerías importadas")
# Out:
# ✅ Librerías importadas

# %% [markdown]
# ## 2. Carga de datos

# %%
# Cargar datos
df = pd.read_csv('../data/processed/youtoxic_english_1000_processed.csv')
with open('../data/processed/y_train.pkl', 'rb') as f:
    y_train = pickle.load(f)
with open('../data/processed/y_test.pkl', 'rb') as f:
    y_test = pickle.load(f)

X_train_text = df[df.index.isin(range(len(y_train)))]['Text_processed'].values
X_test_text = df[df.index.isin(range(len(y_train), len(y_train) + len(y_test)))]['Text_processed'].values

print(f"✅ Datos cargados: {len(X_train_text)} train, {len(X_test_text)} test")
print(f"Distribución train: {np.bincount(y_train)}")
print(f"Distribución test: {np.bincount(y_test)}")
# Out:
# ✅ Datos cargados: 800 train, 200 test
# Distribución train: [430 370]
# Distribución test: [108  92]

# %% [markdown]
# ## 3. Vectorización optimizada

# %%
# Vectorización optimizada para reducir overfitting
tfidf = TfidfVectorizer(
    max_features=600,        # Menos features = menos overfitting
    ngram_range=(1, 2),      # Bigramas para captar contexto
    min_df=3,                # Filtrar palabras raras
    max_df=0.85,             # Filtrar palabras muy comunes
    stop_words='english',
    sublinear_tf=True,
    norm='l2'
)

# SIN augmentación (Naive Bayes es simple y no necesita tanto)
X_train_tfidf = tfidf.fit_transform(X_train_text)
X_test_tfidf = tfidf.transform(X_test_text)

print(f"✅ Vectorización: {X_train_tfidf.shape[1]} features")
print(f"   Train shape: {X_train_tfidf.shape}")
print(f"   Test shape: {X_test_tfidf.shape}")
# Out:
# ✅ Vectorización: 600 features
#    Train shape: (800, 600)
#    Test shape: (200, 600)

# %% [markdown]
# ## 4. Función de Evaluación

# %%
def evaluate_model(model, X_train, X_test, y_train, y_test):
    """Evalúa modelo y retorna métricas."""
    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)
    
    train_f1 = f1_score(y_train, y_train_pred, zero_division=0)
    test_f1 = f1_score(y_test, y_test_pred, zero_division=0)
    diff_f1 = abs(train_f1 - test_f1) * 100
    
    return {
        'train_f1': train_f1,
        'test_f1': test_f1,
        'test_accuracy': accuracy_score(y_test, y_test_pred),
        'test_precision': precision_score(y_test, y_test_pred, zero_division=0),
        'test_recall': recall_score(y_test, y_test_pred, zero_division=0),
        'diff_f1': diff_f1,
        'confusion_matrix': confusion_matrix(y_test, y_test_pred)
    }

# %% [markdown]
# ## 5. Función Objetivo para Optuna

# %%
def objective(trial):
    """
    Función objetivo para Naive Bayes:
    - Regularización con alpha (smoothing parameter)
    - Priorizar overfitting <5% y F1 >0.55
    - Naive Bayes es simple, menos propenso a overfitting
    """
    # Alpha: parámetro de regularización (smoothing)
    # Valores más altos = más regularización = menos overfitting
    alpha = trial.suggest_float('alpha', 0.1, 10.0, log=True)
    
    # fit_prior: si usar las probabilidades a priori de las clases
    fit_prior = trial.suggest_categorical('fit_prior', [True, False])
    
    model = MultinomialNB(
        alpha=alpha,
        fit_prior=fit_prior,
        class_prior=None  # Calcular automáticamente
    )
    
    model.fit(X_train_tfidf, y_train)
    results = evaluate_model(model, X_train_tfidf, X_test_tfidf, y_train, y_test)
    
    # Rechazar modelos inútiles
    if results['test_f1'] < 0.50:
        return -10.0
    
    # Rechazar overfitting extremo
    if results['diff_f1'] > 8.0:
        return -20.0
    
    # PRIORIDAD 1: Control de overfitting
    if results['diff_f1'] < 5.0:
        overfitting_bonus = (5.0 - results['diff_f1']) * 0.50  # Bonus grande
    else:
        overfitting_bonus = 0
    
    # PRIORIDAD 2: Penalización por overfitting
    if results['diff_f1'] > 5.0:
        overfitting_penalty = ((results['diff_f1'] - 5.0) ** 2) * 0.05
    else:
        overfitting_penalty = 0
    
    # PRIORIDAD 3: F1-score base
    base_score = results['test_f1'] * 0.4
    
    score = base_score + overfitting_bonus - overfitting_penalty
    return score

print("✅ Función objetivo definida (prioriza overfitting <5%)")
# Out:
# ✅ Función objetivo definida (prioriza overfitting <5%)

# %% [markdown]
# ## 6. Optimización con Optuna

# %%
study = optuna.create_study(direction='maximize', sampler=optuna.samplers.TPESampler(seed=42))

print("="*80)
print("OPTIMIZACIÓN NAIVE BAYES - CONTROL DE OVERFITTING")
print("="*80)
print("✅ SIN augmentación (Naive Bayes es simple)")
print("✅ Regularización con alpha (smoothing parameter)")
print("✅ Vectorizador simplificado (600 features)")
print("✅ Penalización por overfitting >5%")
print("\nObjetivo: F1 > 0.55 Y overfitting < 5%")
print("Trials: 150")
print("-"*80)

study.optimize(objective, n_trials=150, show_progress_bar=True)

print("\n✅ Optimización completada")
# Out:
# [I 2025-12-04 09:20:57,456] A new study created in memory with name: no-name-4c03dce4-aaf0-4eda-8328-80c82d886f82
# ================================================================================
# OPTIMIZACIÓN NAIVE BAYES - CONTROL DE OVERFITTING
# ================================================================================
# ✅ SIN augmentación (Naive Bayes es simple)
# ✅ Regularización con alpha (smoothing parameter)
# ✅ Vectorizador simplificado (600 features)
# ✅ Penalización por overfitting >5%
#
# Objetivo: F1 > 0.55 Y overfitting < 5%
# Trials: 150
# --------------------------------------------------------------------------------
#   0%|          | 0/150 [00:00<?, ?it/s]
# [I 2025-12-04 09:20:57,543] Trial 0 finished with value: -10.0 and parameters: {'alpha': 0.5611516415334505, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:20:57,573] Trial 1 finished with value: -10.0 and parameters: {'alpha': 1.5751320499779735, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:20:57,604] Trial 2 finished with value: -10.0 and parameters: {'alpha': 0.13066739238053282, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:20:57,636] Trial 3 finished with value: -10.0 and parameters: {'alpha': 2.607024758370768, 'fit_prior': False}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:20:57,667] Trial 4 finished with value: -10.0 and parameters: {'alpha': 4.622589001020832, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:20:57,701] Trial 5 finished with value: -10.0 and parameters: {'alpha': 0.2327067708383781, 'fit_prior': False}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:20:57,727] Trial 6 finished with value: -10.0 and parameters: {'alpha': 0.7309539835912913, 'fit_prior': False}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:20:57,764] Trial 7 finished with value: -10.0 and parameters: {'alpha': 0.19010245319870356, 'fit_prior': False}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:20:57,792] Trial 8 finished with value: -10.0 and parameters: {'alpha': 0.8168455894760165, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:20:57,820] Trial 9 finished with value: -10.0 and parameters: {'alpha': 1.0677482709481354, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:20:57,863] Trial 10 finished with value: -10.0 and parameters: {'alpha': 7.76735381623706, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:20:57,903] Trial 11 finished with value: -10.0 and parameters: {'alpha': 1.646989402572962, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:20:57,939] Trial 12 finished with value: -10.0 and parameters: {'alpha': 0.460505719895977, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:20:57,977] Trial 13 finished with value: -10.0 and parameters: {'alpha': 1.9978187556423745, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:20:58,018] Trial 14 finished with value: -10.0 and parameters: {'alpha': 0.4096102645744614, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:20:58,053] Trial 15 finished with value: -10.0 and parameters: {'alpha': 1.3539044735336498, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:20:58,090] Trial 16 finished with value: -10.0 and parameters: {'alpha': 2.9765092251180736, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:20:58,129] Trial 17 finished with value: -10.0 and parameters: {'alpha': 0.4847904579735337, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:20:58,164] Trial 18 finished with value: -10.0 and parameters: {'alpha': 1.1071834316998148, 'fit_prior': False}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:20:58,201] Trial 19 finished with value: -10.0 and parameters: {'alpha': 0.688917463810979, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:20:58,239] Trial 20 finished with value: -10.0 and parameters: {'alpha': 0.30216877678758974, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:20:58,273] Trial 21 finished with value: -10.0 and parameters: {'alpha': 0.1625548845333064, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:20:58,310] Trial 22 finished with value: -10.0 and parameters: {'alpha': 0.11013915949826689, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:20:58,350] Trial 23 finished with value: -10.0 and parameters: {'alpha': 0.1020929451538757, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:20:58,384] Trial 24 finished with value: -10.0 and parameters: {'alpha': 0.3072970457845412, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:20:58,422] Trial 25 finished with value: -10.0 and parameters: {'alpha': 0.6422551831170714, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:20:58,459] Trial 26 finished with value: -10.0 and parameters: {'alpha': 0.1422214638387498, 'fit_prior': False}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:20:58,495] Trial 27 finished with value: -10.0 and parameters: {'alpha': 0.22682762572146606, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:20:58,533] Trial 28 finished with value: -10.0 and parameters: {'alpha': 1.23623323300942, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:20:58,573] Trial 29 finished with value: -10.0 and parameters: {'alpha': 2.2018186447438377, 'fit_prior': False}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:20:58,607] Trial 30 finished with value: -10.0 and parameters: {'alpha': 0.8391247009606101, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:20:58,647] Trial 31 finished with value: -10.0 and parameters: {'alpha': 3.3292569257128153, 'fit_prior': False}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:20:58,686] Trial 32 finished with value: -10.0 and parameters: {'alpha': 1.8278955249850244, 'fit_prior': False}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:20:58,723] Trial 33 finished with value: -10.0 and parameters: {'alpha': 1.442554065073418, 'fit_prior': False}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:20:58,762] Trial 34 finished with value: -10.0 and parameters: {'alpha': 2.612956489385608, 'fit_prior': False}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:20:58,801] Trial 35 finished with value: -10.0 and parameters: {'alpha': 3.359094375109347, 'fit_prior': False}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:20:58,838] Trial 36 finished with value: -10.0 and parameters: {'alpha': 4.496448242471308, 'fit_prior': False}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:20:58,881] Trial 37 finished with value: -10.0 and parameters: {'alpha': 0.912666706872024, 'fit_prior': False}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:20:58,919] Trial 38 finished with value: -10.0 and parameters: {'alpha': 1.5659306145110963, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:20:58,955] Trial 39 finished with value: -10.0 and parameters: {'alpha': 1.0556741651125559, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:20:58,993] Trial 40 finished with value: -10.0 and parameters: {'alpha': 0.19860065817724945, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:20:59,033] Trial 41 finished with value: -10.0 and parameters: {'alpha': 2.1574781408335526, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:20:59,069] Trial 42 finished with value: -10.0 and parameters: {'alpha': 4.765629007898928, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:20:59,106] Trial 43 finished with value: -10.0 and parameters: {'alpha': 8.84645820180868, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:20:59,149] Trial 44 finished with value: -10.0 and parameters: {'alpha': 0.5759243658403238, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:20:59,183] Trial 45 finished with value: -10.0 and parameters: {'alpha': 0.7691771674875776, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:20:59,219] Trial 46 finished with value: -10.0 and parameters: {'alpha': 1.3203307416490258, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:20:59,259] Trial 47 finished with value: -10.0 and parameters: {'alpha': 0.2988092072471754, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:20:59,294] Trial 48 finished with value: -10.0 and parameters: {'alpha': 1.7565063131361252, 'fit_prior': False}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:20:59,331] Trial 49 finished with value: -10.0 and parameters: {'alpha': 5.93619336951923, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:20:59,368] Trial 50 finished with value: -10.0 and parameters: {'alpha': 0.9809387811796177, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:20:59,403] Trial 51 finished with value: -10.0 and parameters: {'alpha': 0.37511000160514363, 'fit_prior': False}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:20:59,440] Trial 52 finished with value: -10.0 and parameters: {'alpha': 0.13878043837923876, 'fit_prior': False}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:20:59,483] Trial 53 finished with value: -10.0 and parameters: {'alpha': 0.5168686199069988, 'fit_prior': False}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:20:59,521] Trial 54 finished with value: -10.0 and parameters: {'alpha': 0.21444255618395108, 'fit_prior': False}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:20:59,562] Trial 55 finished with value: -10.0 and parameters: {'alpha': 0.25194862370282506, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:20:59,604] Trial 56 finished with value: -10.0 and parameters: {'alpha': 0.15006385082400078, 'fit_prior': False}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:20:59,641] Trial 57 finished with value: -10.0 and parameters: {'alpha': 0.3935358940457086, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:20:59,683] Trial 58 finished with value: -10.0 and parameters: {'alpha': 0.11901019199870289, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:20:59,726] Trial 59 finished with value: -10.0 and parameters: {'alpha': 0.17146074497563557, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:20:59,764] Trial 60 finished with value: -10.0 and parameters: {'alpha': 0.12544518510078054, 'fit_prior': False}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:20:59,805] Trial 61 finished with value: -10.0 and parameters: {'alpha': 0.712941081337653, 'fit_prior': False}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:20:59,847] Trial 62 finished with value: -10.0 and parameters: {'alpha': 0.65607545540129, 'fit_prior': False}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:20:59,885] Trial 63 finished with value: -10.0 and parameters: {'alpha': 0.17712414930110515, 'fit_prior': False}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:20:59,926] Trial 64 finished with value: -10.0 and parameters: {'alpha': 0.4622033892985006, 'fit_prior': False}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:20:59,970] Trial 65 finished with value: -10.0 and parameters: {'alpha': 1.1946542294072016, 'fit_prior': False}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:00,010] Trial 66 finished with value: -10.0 and parameters: {'alpha': 1.111075441547483, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:00,052] Trial 67 finished with value: -10.0 and parameters: {'alpha': 0.852803548644478, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:00,094] Trial 68 finished with value: -10.0 and parameters: {'alpha': 0.5497273688067364, 'fit_prior': False}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:00,133] Trial 69 finished with value: -10.0 and parameters: {'alpha': 1.4380262876511127, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:00,174] Trial 70 finished with value: -10.0 and parameters: {'alpha': 2.495897716735265, 'fit_prior': False}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:00,217] Trial 71 finished with value: -10.0 and parameters: {'alpha': 0.19766356109580324, 'fit_prior': False}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:00,256] Trial 72 finished with value: -10.0 and parameters: {'alpha': 0.10685327573111018, 'fit_prior': False}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:00,298] Trial 73 finished with value: -10.0 and parameters: {'alpha': 0.2665993798670904, 'fit_prior': False}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:00,342] Trial 74 finished with value: -10.0 and parameters: {'alpha': 1.912867265788266, 'fit_prior': False}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:00,378] Trial 75 finished with value: -10.0 and parameters: {'alpha': 0.3648085407531144, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:00,418] Trial 76 finished with value: -10.0 and parameters: {'alpha': 1.6485168485460489, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:00,462] Trial 77 finished with value: -10.0 and parameters: {'alpha': 0.9511820948144966, 'fit_prior': False}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:00,501] Trial 78 finished with value: -10.0 and parameters: {'alpha': 0.15962241037991695, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:00,541] Trial 79 finished with value: -10.0 and parameters: {'alpha': 0.13962894693420058, 'fit_prior': False}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:00,584] Trial 80 finished with value: -10.0 and parameters: {'alpha': 0.41888260976498826, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:00,626] Trial 81 finished with value: -10.0 and parameters: {'alpha': 0.7975730001042812, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:00,668] Trial 82 finished with value: -10.0 and parameters: {'alpha': 0.7110969562847816, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:00,713] Trial 83 finished with value: -10.0 and parameters: {'alpha': 1.2304748725009487, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:00,751] Trial 84 finished with value: -10.0 and parameters: {'alpha': 0.5904224962676716, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:00,795] Trial 85 finished with value: -10.0 and parameters: {'alpha': 0.100883003979925, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:00,838] Trial 86 finished with value: -10.0 and parameters: {'alpha': 1.0123515077658605, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:00,877] Trial 87 finished with value: -10.0 and parameters: {'alpha': 0.6345250720095659, 'fit_prior': False}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:00,917] Trial 88 finished with value: -10.0 and parameters: {'alpha': 0.49189609445645477, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:00,959] Trial 89 finished with value: -10.0 and parameters: {'alpha': 1.552504718245815, 'fit_prior': False}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:00,998] Trial 90 finished with value: -10.0 and parameters: {'alpha': 0.884745138647853, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:01,041] Trial 91 finished with value: -10.0 and parameters: {'alpha': 1.3384735742472438, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:01,085] Trial 92 finished with value: -10.0 and parameters: {'alpha': 1.0596788077360255, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:01,123] Trial 93 finished with value: -10.0 and parameters: {'alpha': 0.7921186906617942, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:01,164] Trial 94 finished with value: -10.0 and parameters: {'alpha': 1.799697108931461, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:01,209] Trial 95 finished with value: -10.0 and parameters: {'alpha': 0.9328479348674936, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:01,247] Trial 96 finished with value: -10.0 and parameters: {'alpha': 1.1335747693301192, 'fit_prior': False}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:01,288] Trial 97 finished with value: -10.0 and parameters: {'alpha': 2.0989088981480206, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:01,332] Trial 98 finished with value: -10.0 and parameters: {'alpha': 3.0040788272616936, 'fit_prior': False}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:01,371] Trial 99 finished with value: -10.0 and parameters: {'alpha': 0.7361434245722651, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:01,410] Trial 100 finished with value: -10.0 and parameters: {'alpha': 0.12529596342224755, 'fit_prior': False}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:01,455] Trial 101 finished with value: -10.0 and parameters: {'alpha': 7.331465848206579, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:01,494] Trial 102 finished with value: -10.0 and parameters: {'alpha': 5.0993262932024, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:01,536] Trial 103 finished with value: -10.0 and parameters: {'alpha': 4.060512102214299, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:01,579] Trial 104 finished with value: -10.0 and parameters: {'alpha': 2.4610827120952066, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:01,617] Trial 105 finished with value: -10.0 and parameters: {'alpha': 0.1935165211268909, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:01,659] Trial 106 finished with value: -10.0 and parameters: {'alpha': 0.6283722849653345, 'fit_prior': False}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:01,702] Trial 107 finished with value: -10.0 and parameters: {'alpha': 9.984144097805775, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:01,742] Trial 108 finished with value: -10.0 and parameters: {'alpha': 0.8889620130475546, 'fit_prior': False}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:01,787] Trial 109 finished with value: -10.0 and parameters: {'alpha': 0.5407918136019979, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:01,830] Trial 110 finished with value: -10.0 and parameters: {'alpha': 0.22342093658972628, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:01,871] Trial 111 finished with value: -10.0 and parameters: {'alpha': 1.2863061521574504, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:01,916] Trial 112 finished with value: -10.0 and parameters: {'alpha': 1.5042943130715933, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:01,959] Trial 113 finished with value: -10.0 and parameters: {'alpha': 1.1830128979573291, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:02,000] Trial 114 finished with value: -10.0 and parameters: {'alpha': 1.6659814699528555, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:02,042] Trial 115 finished with value: -10.0 and parameters: {'alpha': 1.8781818572180482, 'fit_prior': False}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:02,086] Trial 116 finished with value: -10.0 and parameters: {'alpha': 1.347747098110818, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:02,125] Trial 117 finished with value: -10.0 and parameters: {'alpha': 1.0216396395601912, 'fit_prior': False}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:02,167] Trial 118 finished with value: -10.0 and parameters: {'alpha': 2.2304453391288193, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:02,213] Trial 119 finished with value: -10.0 and parameters: {'alpha': 0.17520218475375762, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:02,251] Trial 120 finished with value: -10.0 and parameters: {'alpha': 0.8288059214504363, 'fit_prior': False}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:02,292] Trial 121 finished with value: -10.0 and parameters: {'alpha': 0.6756808410874505, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:02,336] Trial 122 finished with value: -10.0 and parameters: {'alpha': 0.5786204342317813, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:02,375] Trial 123 finished with value: -10.0 and parameters: {'alpha': 0.3354617835776054, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:02,419] Trial 124 finished with value: -10.0 and parameters: {'alpha': 0.4335339716497739, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:02,463] Trial 125 finished with value: -10.0 and parameters: {'alpha': 0.47780121508716855, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:02,504] Trial 126 finished with value: -10.0 and parameters: {'alpha': 0.2990528045110593, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:02,546] Trial 127 finished with value: -10.0 and parameters: {'alpha': 0.24095403712148505, 'fit_prior': False}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:02,591] Trial 128 finished with value: -10.0 and parameters: {'alpha': 0.7482345633474473, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:02,633] Trial 129 finished with value: -10.0 and parameters: {'alpha': 0.14894772739047119, 'fit_prior': False}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:02,675] Trial 130 finished with value: -10.0 and parameters: {'alpha': 0.2680766139558156, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:02,724] Trial 131 finished with value: -10.0 and parameters: {'alpha': 1.4846150239545464, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:02,766] Trial 132 finished with value: -10.0 and parameters: {'alpha': 2.014920717967949, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:02,806] Trial 133 finished with value: -10.0 and parameters: {'alpha': 2.716612351506917, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:02,854] Trial 134 finished with value: -10.0 and parameters: {'alpha': 1.7311223163554856, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:02,895] Trial 135 finished with value: -10.0 and parameters: {'alpha': 3.782092492525084, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:02,937] Trial 136 finished with value: -10.0 and parameters: {'alpha': 2.271942528325381, 'fit_prior': False}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:02,982] Trial 137 finished with value: -10.0 and parameters: {'alpha': 6.21095209555458, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:03,022] Trial 138 finished with value: -10.0 and parameters: {'alpha': 1.3997643882702697, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:03,066] Trial 139 finished with value: -10.0 and parameters: {'alpha': 0.20812721179729474, 'fit_prior': False}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:03,111] Trial 140 finished with value: -10.0 and parameters: {'alpha': 1.9480073277276464, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:03,150] Trial 141 finished with value: -10.0 and parameters: {'alpha': 0.5011009380427689, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:03,191] Trial 142 finished with value: -10.0 and parameters: {'alpha': 0.38649496292510704, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:03,237] Trial 143 finished with value: -10.0 and parameters: {'alpha': 0.6198745359479573, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:03,280] Trial 144 finished with value: -10.0 and parameters: {'alpha': 0.5695444133067753, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:03,322] Trial 145 finished with value: -10.0 and parameters: {'alpha': 0.4478912617671186, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:03,369] Trial 146 finished with value: -10.0 and parameters: {'alpha': 0.11456448701689106, 'fit_prior': False}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:03,410] Trial 147 finished with value: -10.0 and parameters: {'alpha': 0.6779920017624147, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:03,455] Trial 148 finished with value: -10.0 and parameters: {'alpha': 0.163974385078779, 'fit_prior': True}. Best is trial 0 with value: -10.0.
# [I 2025-12-04 09:21:03,500] Trial 149 finished with value: -10.0 and parameters: {'alpha': 0.4130720175356914, 'fit_prior': False}. Best is trial 0 with value: -10.0.
#
# ✅ Optimización completada

# %% [markdown]
# ## 7. Evaluación del Mejor Modelo

# %%
# Entrenar mejor modelo
best_params = study.best_params

best_model = MultinomialNB(
    alpha=best_params['alpha'],
    fit_prior=best_params['fit_prior'],
    class_prior=None
)

best_model.fit(X_train_tfidf, y_train)
results = evaluate_model(best_model, X_train_tfidf, X_test_tfidf, y_train, y_test)

print("="*80)
print("RESULTADOS FINALES - NAIVE BAYES")
print("="*80)
print(f"F1-score (train): {results['train_f1']:.4f}")
print(f"F1-score (test): {results['test_f1']:.4f}")
print(f"Accuracy (test): {results['test_accuracy']:.4f}")
print(f"Precision (test): {results['test_precision']:.4f}")
print(f"Recall (test): {results['test_recall']:.4f}")
print(f"Diferencia F1: {results['diff_f1']:.2f}%")
print(f"\nMejores hiperparámetros:")
print(f"  Alpha: {best_params['alpha']:.4f}")
print(f"  Fit prior: {best_params['fit_prior']}")
print(f"\nMatriz de confusión:")
print(results['confusion_matrix'])

if results['diff_f1'] < 5.0 and results['test_f1'] > 0.55:
    print("\n✅✅✅ OBJETIVO CUMPLIDO: Overfitting < 5% Y F1 > 0.55")
elif results['diff_f1'] < 6.0:
    print("\n🎯 MUY CERCA: Overfitting < 6%")
else:
    print("\n⚠️  Overfitting aún alto")

print("="*80)
# Out:
# ================================================================================
# RESULTADOS FINALES - NAIVE BAYES
# ================================================================================
# F1-score (train): 0.7450
# F1-score (test): 0.3286
# Accuracy (test): 0.5300
# Precision (test): 0.4792
# Recall (test): 0.2500
# Diferencia F1: 41.65%
#
# Mejores hiperparámetros:
#   Alpha: 0.5612
#   Fit prior: True
#
# Matriz de confusión:
# [[83 25]
#  [69 23]]
#
# ⚠️  Overfitting aún alto
# ================================================================================

# %% [markdown]
# ## 8. Validación Cruzada

# %%
X_all = tfidf.transform(np.concatenate([X_train_text, X_test_text]))
y_all = np.concatenate([y_train, y_test])

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
cv_scores = cross_val_score(best_model, X_all, y_all, cv=cv, scoring='f1', n_jobs=-1)

print(f"F1-score (CV): {cv_scores.mean():.4f} (+/- {cv_scores.std() * 2:.4f})")
print(f"Scores: {cv_scores}")
# Out:
# F1-score (CV): 0.3937 (+/- 0.0961)
# Scores: [0.47058824 0.42105263 0.37974684 0.36601307 0.33103448]

# %% [markdown]
# ## 9. Guardar Modelo (si cumple objetivos)

# %%
if results['diff_f1'] < 6.0 and results['test_f1'] > 0.55:
    with open('../models/naive_bayes_model.pkl', 'wb') as f:
        pickle.dump(best_model, f)
    with open('../models/naive_bayes_tfidf.pkl', 'wb') as f:
        pickle.dump(tfidf, f)
    
    model_info = {
        'model_type': 'Naive Bayes (MultinomialNB)',
        'hyperparameters': best_params,
        'test_f1': results['test_f1'],
        'diff_f1': results['diff_f1'],
        'cv_f1_mean': cv_scores.mean(),
        'data_augmentation': False
    }
    
    with open('../models/naive_bayes_info.pkl', 'wb') as f:
        pickle.dump(model_info, f)
    
    print("✅ Modelo Naive Bayes guardado")
else:
    print("⚠️  Modelo no guardado (no cumple objetivos)")
# Out:
# ⚠️  Modelo no guardado (no cumple objetivos)
