# %% [markdown]
# # Random Forest - Reducción de Overfitting
#
# ## Objetivo
# Probar Random Forest como alternativa a SVM para reducir overfitting manteniendo F1-score > 0.55.
#
# ## Ventajas de Random Forest
# - ✅ Control natural de overfitting (max_depth, min_samples_leaf)
# - ✅ Menos sensible a hiperparámetros extremos
# - ✅ Maneja bien datos dispersos (TF-IDF)
# - ✅ No requiere normalización
# - ✅ Menos propenso a F1=0 que SVM lineal

# %% [markdown]
# ## 1. Importación de librerías

# %%
import pandas as pd
import numpy as np
import pickle
import random

from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import cross_val_score, StratifiedKFold
import optuna

from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    confusion_matrix
)

np.random.seed(42)
random.seed(42)

print("✅ Librerías importadas")
# Out:
# ✅ Librerías importadas

# %% [markdown]
# ## 2. Carga de datos

# %%
# Cargar datos
df = pd.read_csv('../data/processed/youtoxic_english_1000_processed.csv')
with open('../data/processed/y_train.pkl', 'rb') as f:
    y_train = pickle.load(f)
with open('../data/processed/y_test.pkl', 'rb') as f:
    y_test = pickle.load(f)

X_train_text = df[df.index.isin(range(len(y_train)))]['Text_processed'].values
X_test_text = df[df.index.isin(range(len(y_train), len(y_train) + len(y_test)))]['Text_processed'].values

print(f"✅ Datos cargados: {len(X_train_text)} train, {len(X_test_text)} test")
print(f"Distribución train: {np.bincount(y_train)}")
print(f"Distribución test: {np.bincount(y_test)}")
# Out:
# ✅ Datos cargados: 800 train, 200 test
# Distribución train: [430 370]
# Distribución test: [108  92]

# %% [markdown]
# ## 3. Vectorización (misma que SVM mejorada)

# %%
# Vectorización mejorada (misma que en SVM)
tfidf = TfidfVectorizer(
    max_features=800,        # Más features
    ngram_range=(1, 2),      # Bigramas
    min_df=3,                # Menos restrictivo
    max_df=0.85,             # Más permisivo
    stop_words='english',
    sublinear_tf=True,
    norm='l2'
)

# SIN augmentación inicialmente (Random Forest maneja mejor el dataset pequeño)
X_train_tfidf = tfidf.fit_transform(X_train_text)
X_test_tfidf = tfidf.transform(X_test_text)

print(f"✅ Vectorización: {X_train_tfidf.shape[1]} features")
print(f"   Train shape: {X_train_tfidf.shape}")
print(f"   Test shape: {X_test_tfidf.shape}")
# Out:
# ✅ Vectorización: 800 features
#    Train shape: (800, 800)
#    Test shape: (200, 800)

# %% [markdown]
# ## 4. Función de Evaluación

# %%
def evaluate_model(model, X_train, X_test, y_train, y_test):
    """Evalúa modelo y retorna métricas."""
    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)
    
    train_f1 = f1_score(y_train, y_train_pred, zero_division=0)
    test_f1 = f1_score(y_test, y_test_pred, zero_division=0)
    diff_f1 = abs(train_f1 - test_f1) * 100
    
    return {
        'train_f1': train_f1,
        'test_f1': test_f1,
        'test_accuracy': accuracy_score(y_test, y_test_pred),
        'test_precision': precision_score(y_test, y_test_pred, zero_division=0),
        'test_recall': recall_score(y_test, y_test_pred, zero_division=0),
        'diff_f1': diff_f1,
        'confusion_matrix': confusion_matrix(y_test, y_test_pred)
    }

# %% [markdown]
# ## 5. Función Objetivo para Optuna

# %%
def objective(trial):
    """
    Función objetivo para Random Forest:
    - Control natural de overfitting con max_depth, min_samples_leaf
    - Prioriza overfitting <5% y F1 >0.55
    """
    # Hiperparámetros que controlan overfitting naturalmente
    n_estimators = trial.suggest_int('n_estimators', 50, 300)
    max_depth = trial.suggest_int('max_depth', 3, 15)  # Limita profundidad
    min_samples_split = trial.suggest_int('min_samples_split', 5, 20)  # Controla división
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 2, 10)  # Controla hojas
    max_features = trial.suggest_categorical('max_features', ['sqrt', 'log2'])  # Feature sampling
    
    model = RandomForestClassifier(
        n_estimators=n_estimators,
        max_depth=max_depth,
        min_samples_split=min_samples_split,
        min_samples_leaf=min_samples_leaf,
        max_features=max_features,
        class_weight='balanced',  # Balance de clases
        random_state=42,
        n_jobs=-1
    )
    
    model.fit(X_train_tfidf, y_train)
    results = evaluate_model(model, X_train_tfidf, X_test_tfidf, y_train, y_test)
    
    # Rechazar modelos inútiles
    if results['test_f1'] < 0.55:
        return -10.0
    
    # Rechazar overfitting extremo
    if results['diff_f1'] > 6.0:
        return -20.0
    
    # Rechazar recall extremo
    if results['test_recall'] >= 0.95:
        return -15.0
    
    # PRIORIDAD 1: Control de overfitting
    if results['diff_f1'] < 5.0:
        overfitting_bonus = (5.0 - results['diff_f1']) * 0.50  # Bonus grande
    else:
        overfitting_bonus = 0
    
    # PRIORIDAD 2: Penalización por overfitting
    if results['diff_f1'] > 5.0:
        overfitting_penalty = ((results['diff_f1'] - 5.0) ** 2) * 0.05
    else:
        overfitting_penalty = 0
    
    # PRIORIDAD 3: Penalizar recall extremo
    recall_penalty = 0
    if results['test_recall'] > 0.80:
        recall_penalty = ((results['test_recall'] - 0.80) ** 2) * 0.40
    
    # PRIORIDAD 4: F1-score base
    base_score = results['test_f1'] * 0.3
    
    score = base_score + overfitting_bonus - overfitting_penalty - recall_penalty
    return score

print("✅ Función objetivo definida (prioriza overfitting <5%)")
# Out:
# ✅ Función objetivo definida (prioriza overfitting <5%)

# %% [markdown]
# ## 6. Optimización con Optuna

# %%
study = optuna.create_study(direction='maximize', sampler=optuna.samplers.TPESampler(seed=42))

print("="*80)
print("OPTIMIZACIÓN RANDOM FOREST - CONTROL DE OVERFITTING")
print("="*80)
print("✅ SIN augmentación (RF maneja mejor dataset pequeño)")
print("✅ Control natural de overfitting (max_depth, min_samples_leaf)")
print("✅ Class weights balanceados")
print("✅ Feature sampling (sqrt/log2)")
print("✅ Penalización por overfitting >5%")
print("\nObjetivo: F1 > 0.55 Y overfitting < 5%")
print("Trials: 150")
print("-"*80)

study.optimize(objective, n_trials=150, show_progress_bar=True)

print("\n✅ Optimización completada")
# Out:
# [I 2025-12-03 12:41:40,485] A new study created in memory with name: no-name-96a4f7a5-28f7-48b9-8fcf-c63b0150f276
# ================================================================================
# OPTIMIZACIÓN RANDOM FOREST - CONTROL DE OVERFITTING
# ================================================================================
# ✅ SIN augmentación (RF maneja mejor dataset pequeño)
# ✅ Control natural de overfitting (max_depth, min_samples_leaf)
# ✅ Class weights balanceados
# ✅ Feature sampling (sqrt/log2)
# ✅ Penalización por overfitting >5%
#
# Objetivo: F1 > 0.55 Y overfitting < 5%
# Trials: 150
# --------------------------------------------------------------------------------
#   0%|          | 0/150 [00:00<?, ?it/s]
# [I 2025-12-03 12:41:40,914] Trial 0 finished with value: -10.0 and parameters: {'n_estimators': 144, 'max_depth': 15, 'min_samples_split': 16, 'min_samples_leaf': 7, 'max_features': 'sqrt'}. Best is trial 0 with value: -10.0.
# [I 2025-12-03 12:41:41,096] Trial 1 finished with value: -10.0 and parameters: {'n_estimators': 64, 'max_depth': 14, 'min_samples_split': 14, 'min_samples_leaf': 8, 'max_features': 'log2'}. Best is trial 0 with value: -10.0.
# [I 2025-12-03 12:41:41,688] Trial 2 finished with value: -10.0 and parameters: {'n_estimators': 258, 'max_depth': 5, 'min_samples_split': 7, 'min_samples_leaf': 3, 'max_features': 'log2'}. Best is trial 0 with value: -10.0.
# [I 2025-12-03 12:41
 'max_depth': 14, 'min_samples_split': 6, 'min_samples_leaf': 5, 'max_features': 'sqrt'}. Best is trial 0 with value: -10.0.
# [I 2025-12-03 12:42:22,599] Trial 121 finished with value: -10.0 and parameters: {'n_estimators': 139, 'max_depth': 15, 'min_samples_split': 10, 'min_samples_leaf': 8, 'max_features': 'sqrt'}. Best is trial 0 with value: -10.0.
# [I 2025-12-03 12:42:22,859] Trial 122 finished with value: -10.0 and parameters: {'n_estimators': 107, 'max_depth': 15, 'min_samples_split': 13, 'min_samples_leaf': 8, 'max_features': 'sqrt'}. Best is trial 0 with value: -10.0.
# [I 2025-12-03 12:42:23,158] Trial 123 finished with value: -10.0 and parameters: {'n_estimators': 129, 'max_depth': 15, 'min_samples_split': 9, 'min_samples_leaf': 8, 'max_features': 'sqrt'}. Best is trial 0 with value: -10.0.
# [I 2025-12-03 12:42:23,331] Trial 124 finished with value: -10.0 and parameters: {'n_estimators': 62, 'max_depth': 14, 'min_samples_split': 7, 'min_samples_leaf': 7, 'max_features': 'sqrt'}. Best is trial 0 with value: -10.0.
# [I 2025-12-03 12:42:23,825] Trial 125 finished with value: -10.0 and parameters: {'n_estimators': 259, 'max_depth': 4, 'min_samples_split': 11, 'min_samples_leaf': 6, 'max_features': 'log2'}. Best is trial 0 with value: -10.0.
# [I 2025-12-03 12:42:24,098] Trial 126 finished with value: -10.0 and parameters: {'n_estimators': 123, 'max_depth': 14, 'min_samples_split': 12, 'min_samples_leaf': 8, 'max_features': 'sqrt'}. Best is trial 0 with value: -10.0.
# [I 2025-12-03 12:42:24,419] Trial 127 finished with value: -10.0 and parameters: {'n_estimators': 147, 'max_depth': 15, 'min_samples_split': 14, 'min_samples_leaf': 9, 'max_features': 'log2'}. Best is trial 0 with value: -10.0.
# [I 2025-12-03 12:42:24,606] Trial 128 finished with value: -10.0 and parameters: {'n_estimators': 79, 'max_depth': 12, 'min_samples_split': 15, 'min_samples_leaf': 3, 'max_features': 'sqrt'}. Best is trial 0 with value: -10.0.
# [I 2025-12-03 12:42:24,944] Trial 129 finished with value: -10.0 and parameters: {'n_estimators': 165, 'max_depth': 5, 'min_samples_split': 7, 'min_samples_leaf': 9, 'max_features': 'log2'}. Best is trial 0 with value: -10.0.
# [I 2025-12-03 12:42:25,230] Trial 130 finished with value: -10.0 and parameters: {'n_estimators': 134, 'max_depth': 9, 'min_samples_split': 8, 'min_samples_leaf': 7, 'max_features': 'sqrt'}. Best is trial 0 with value: -10.0.
# [I 2025-12-03 12:42:25,489] Trial 131 finished with value: -10.0 and parameters: {'n_estimators': 108, 'max_depth': 12, 'min_samples_split': 17, 'min_samples_leaf': 5, 'max_features': 'log2'}. Best is trial 0 with value: -10.0.
# [I 2025-12-03 12:42:25,733] Trial 132 finished with value: -10.0 and parameters: {'n_estimators': 97, 'max_depth': 13, 'min_samples_split': 16, 'min_samples_leaf': 4, 'max_features': 'log2'}. Best is trial 0 with value: -10.0.
# [I 2025-12-03 12:42:26,000] Trial 133 finished with value: -10.0 and parameters: {'n_estimators': 104, 'max_depth': 12, 'min_samples_split': 15, 'min_samples_leaf': 6, 'max_features': 'log2'}. Best is trial 0 with value: -10.0.
# [I 2025-12-03 12:42:26,272] Trial 134 finished with value: -10.0 and parameters: {'n_estimators': 116, 'max_depth': 11, 'min_samples_split': 16, 'min_samples_leaf': 5, 'max_features': 'log2'}. Best is trial 0 with value: -10.0.
# [I 2025-12-03 12:42:26,560] Trial 135 finished with value: -10.0 and parameters: {'n_estimators': 125, 'max_depth': 13, 'min_samples_split': 20, 'min_samples_leaf': 3, 'max_features': 'log2'}. Best is trial 0 with value: -10.0.
# [I 2025-12-03 12:42:26,833] Trial 136 finished with value: -10.0 and parameters: {'n_estimators': 114, 'max_depth': 14, 'min_samples_split': 19, 'min_samples_leaf': 4, 'max_features': 'log2'}. Best is trial 0 with value: -10.0.
# [I 2025-12-03 12:42:27,177] Trial 137 finished with value: -10.0 and parameters: {'n_estimators': 91, 'max_depth': 11, 'min_samples_split': 17, 'min_samples_leaf': 6, 'max_features': 'sqrt'}. Best is trial 0 with value: -10.0.
# [I 2025-12-03 12:42:27,589] Trial 138 finished with value: -10.0 and parameters: {'n_estimators': 192, 'max_depth': 14, 'min_samples_split': 6, 'min_samples_leaf': 10, 'max_features': 'log2'}. Best is trial 0 with value: -10.0.
# [I 2025-12-03 12:42:27,941] Trial 139 finished with value: -10.0 and parameters: {'n_estimators': 169, 'max_depth': 15, 'min_samples_split': 18, 'min_samples_leaf': 8, 'max_features': 'sqrt'}. Best is trial 0 with value: -10.0.
# [I 2025-12-03 12:42:28,104] Trial 140 finished with value: -10.0 and parameters: {'n_estimators': 60, 'max_depth': 5, 'min_samples_split': 15, 'min_samples_leaf': 8, 'max_features': 'log2'}. Best is trial 0 with value: -10.0.
# [I 2025-12-03 12:42:28,292] Trial 141 finished with value: -10.0 and parameters: {'n_estimators': 70, 'max_depth': 6, 'min_samples_split': 12, 'min_samples_leaf': 10, 'max_features': 'log2'}. Best is trial 0 with value: -10.0.
# [I 2025-12-03 12:42:28,498] Trial 142 finished with value: -10.0 and parameters: {'n_estimators': 94, 'max_depth': 4, 'min_samples_split': 13, 'min_samples_leaf': 9, 'max_features': 'log2'}. Best is trial 0 with value: -10.0.
# [I 2025-12-03 12:42:28,703] Trial 143 finished with value: -10.0 and parameters: {'n_estimators': 88, 'max_depth': 10, 'min_samples_split': 9, 'min_samples_leaf': 10, 'max_features': 'log2'}. Best is trial 0 with value: -10.0.
# [I 2025-12-03 12:42:28,888] Trial 144 finished with value: -10.0 and parameters: {'n_estimators': 51, 'max_depth': 13, 'min_samples_split': 12, 'min_samples_leaf': 3, 'max_features': 'log2'}. Best is trial 0 with value: -10.0.
# [I 2025-12-03 12:42:29,154] Trial 145 finished with value: -10.0 and parameters: {'n_estimators': 78, 'max_depth': 8, 'min_samples_split': 14, 'min_samples_leaf': 9, 'max_features': 'sqrt'}. Best is trial 0 with value: -10.0.
# [I 2025-12-03 12:42:29,348] Trial 146 finished with value: -10.0 and parameters: {'n_estimators': 68, 'max_depth': 7, 'min_samples_split': 17, 'min_samples_leaf': 8, 'max_features': 'log2'}. Best is trial 0 with value: -10.0.
# [I 2025-12-03 12:42:29,791] Trial 147 finished with value: -10.0 and parameters: {'n_estimators': 199, 'max_depth': 6, 'min_samples_split': 11, 'min_samples_leaf': 7, 'max_features': 'sqrt'}. Best is trial 0 with value: -10.0.
# [I 2025-12-03 12:42:30,230] Trial 148 finished with value: -10.0 and parameters: {'n_estimators': 210, 'max_depth': 12, 'min_samples_split': 16, 'min_samples_leaf': 10, 'max_features': 'log2'}. Best is trial 0 with value: -10.0.
# [I 2025-12-03 12:42:30,622] Trial 149 finished with value: -10.0 and parameters: {'n_estimators': 176, 'max_depth': 3, 'min_samples_split': 13, 'min_samples_leaf': 2, 'max_features': 'sqrt'}. Best is trial 0 with value: -10.0.
#
# ✅ Optimización completada

# %% [markdown]
# ## 7. Evaluación del Mejor Modelo

# %%
# Entrenar mejor modelo
best_params = study.best_params

best_model = RandomForestClassifier(
    n_estimators=best_params['n_estimators'],
    max_depth=best_params['max_depth'],
    min_samples_split=best_params['min_samples_split'],
    min_samples_leaf=best_params['min_samples_leaf'],
    max_features=best_params['max_features'],
    class_weight='balanced',
    random_state=42,
    n_jobs=-1
)

best_model.fit(X_train_tfidf, y_train)
results = evaluate_model(best_model, X_train_tfidf, X_test_tfidf, y_train, y_test)

print("="*80)
print("RESULTADOS FINALES - RANDOM FOREST")
print("="*80)
print(f"F1-score (test): {results['test_f1']:.4f}")
print(f"Accuracy (test): {results['test_accuracy']:.4f}")
print(f"Precision (test): {results['test_precision']:.4f}")
print(f"Recall (test): {results['test_recall']:.4f}")
print(f"Diferencia F1: {results['diff_f1']:.2f}%")
print(f"\nMatriz de confusión:")
print(results['confusion_matrix'])

if results['diff_f1'] < 5.0 and results['test_f1'] > 0.55:
    print("\n✅✅✅ OBJETIVO CUMPLIDO: Overfitting < 5% Y F1 > 0.55")
elif results['diff_f1'] < 6.0:
    print("\n🎯 MUY CERCA: Overfitting < 6%")
else:
    print("\n⚠️  Overfitting aún alto")

print("="*80)
# Out:
# ================================================================================
# RESULTADOS FINALES - RANDOM FOREST
# ================================================================================
# F1-score (test): 0.4731
# Accuracy (test): 0.5100
# Precision (test): 0.4681
# Recall (test): 0.4783
# Diferencia F1: 27.27%
#
# Matriz de confusión:
# [[58 50]
#  [48 44]]
#
# ⚠️  Overfitting aún alto
# ================================================================================

# %% [markdown]
# ## 8. Validación Cruzada

# %%
from scipy.sparse import vstack
X_all = vstack([X_train_tfidf, X_test_tfidf])
y_all = np.concatenate([y_train, y_test])

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
cv_scores = cross_val_score(best_model, X_all, y_all, cv=cv, scoring='f1', n_jobs=-1)

print(f"F1-score (CV): {cv_scores.mean():.4f} (+/- {cv_scores.std() * 2:.4f})")
print(f"Scores: {cv_scores}")
# Out:
# F1-score (CV): 0.4972 (+/- 0.0724)
# Scores: [0.53456221 0.53608247 0.47777778 0.44       0.49740933]

# %% [markdown]
# ## 9. Guardar Modelo (si cumple objetivos)

# %%
if results['diff_f1'] < 6.0 and results['test_f1'] > 0.55:
    with open('../models/random_forest_model.pkl', 'wb') as f:
        pickle.dump(best_model, f)
    with open('../models/random_forest_tfidf.pkl', 'wb') as f:
        pickle.dump(tfidf, f)
    
    model_info = {
        'model_type': 'RandomForest',
        'hyperparameters': best_params,
        'test_f1': results['test_f1'],
        'diff_f1': results['diff_f1'],
        'cv_f1_mean': cv_scores.mean(),
        'data_augmentation': False
    }
    
    with open('../models/random_forest_info.pkl', 'wb') as f:
        pickle.dump(model_info, f)
    
    print("✅ Modelo Random Forest guardado")
else:
    print("⚠️  Modelo no guardado (no cumple objetivos)")
# Out:
# ⚠️  Modelo no guardado (no cumple objetivos)

# %% [markdown]
# ## 10. Análisis de Feature Importance

# %%
# Feature importance (top 20)
feature_names = tfidf.get_feature_names_out()
importances = best_model.feature_importances_
indices = np.argsort(importances)[::-1][:20]

print("Top 20 features más importantes:")
print("-"*50)
for i in range(20):
    print(f"{i+1:2d}. {feature_names[indices[i]]:30s} {importances[indices[i]]:.4f}")
# Out:
# Top 20 features más importantes:
# --------------------------------------------------
#  1. cnn                            0.0304
#  2. black                          0.0265
#  3. time                           0.0252
#  4. look                           0.0249
#  5. woman                          0.0227
#  6. good                           0.0221
#  7. protester                      0.0217
#  8. police                         0.0194
#  9. people                         0.0185
# 10. love                           0.0175
# 11. white                          0.0170
# 12. law                            0.0164
# 13. know                           0.0157
# 14. run                            0.0151
# 15. street                         0.0130
# 16. government                     0.0125
# 17. evidence                       0.0124
# 18. world                          0.0122
# 19. car                            0.0122
# 20. shit                           0.0119
